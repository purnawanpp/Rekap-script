# %% [markdown]
# <a href="https://colab.research.google.com/github/purnawanpp/Rekap-script/blob/main/MMGBSA_NAMD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# wget https://www.ks.uiuc.edu/Research/vmd/vmd-1.9.4/files/alpha/vmd-1.9.4a51.bin.LINUXAMD64-CUDA102-OptiX650-OSPRay185.opengl.tar.gz
# tar -zxf vmd-1.9.4a51.bin.LINUXAMD64-CUDA102-OptiX650-OSPRay185.opengl.tar.gz
# cd vmd-1.9.4a51/
# ./configure
# cd src
# sudo make install
# Out:
# using configure.options: LINUXAMD64 OPENGL OPENGLPBUFFER FLTK TK ACTC CUDA IMD LIBSBALL XINERAMA XINPUT LIBOPTIX LIBOSPRAY LIBTACHYON LIBPNG ZLIB VRPN NETCDF COLVARS TCL PYTHON PTHREADS NUMPY SILENT ICC
# Info: /bin/csh shell not found, installing Bourne shell startup script instead
# Make sure /usr/local/bin/vmd is in your path.
# VMD installation complete.  Enjoy!
# --2023-01-12 01:42:20--  https://www.ks.uiuc.edu/Research/vmd/vmd-1.9.4/files/alpha/vmd-1.9.4a51.bin.LINUXAMD64-CUDA102-OptiX650-OSPRay185.opengl.tar.gz
# Resolving www.ks.uiuc.edu (www.ks.uiuc.edu)... 130.126.120.43
# Connecting to www.ks.uiuc.edu (www.ks.uiuc.edu)|130.126.120.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65962637 (63M) [application/x-gzip]
# Saving to: ‘vmd-1.9.4a51.bin.LINUXAMD64-CUDA102-OptiX650-OSPRay185.opengl.tar.gz.2’
#
#      0K .......... .......... .......... .......... ..........  0% 1001K 64s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NAMD
# Out:
# /content/drive/MyDrive/NAMD

# %%
# !vmd
# Out:
# /usr/local/lib/vmd/vmd_LINUXAMD64: /usr/lib64-nvidia/libGL.so.1: no version information available (required by /usr/local/lib/vmd/vmd_LINUXAMD64)
# Info) VMD for LINUXAMD64, version 1.9.4a51 (December 21, 2020)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 2 CPUs detected.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info)   Detected VM or hypervisor execution environment
# Info) Free system memory: 12GB (93%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Tesla T4             40 SM_7.5 1.6 GHz, 15GB RAM SP32 AE3 ZC
# ...

# %% [markdown]
# Download and install NAMD, run MMGBSA

# %%
# %cd /content/
# Out:
# /content

# %%
# !wget https://www.ks.uiuc.edu/Research/namd/alpha/3.0alpha/download/NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA-SingleNode.tar.gz
# Out:
# --2023-01-12 00:51:28--  https://www.ks.uiuc.edu/Research/namd/alpha/3.0alpha/download/NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA-SingleNode.tar.gz
# Resolving www.ks.uiuc.edu (www.ks.uiuc.edu)... 130.126.120.43
# Connecting to www.ks.uiuc.edu (www.ks.uiuc.edu)|130.126.120.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240222547 (229M) [application/x-gzip]
# Saving to: ‘NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA-SingleNode.tar.gz’
#
# NAMD_3.0alpha13_Lin 100%[===================>] 229.09M  28.7MB/s    in 8.8s
#
# 2023-01-12 00:51:41 (26.1 MB/s) - ‘NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA-SingleNode.tar.gz’ saved [240222547/240222547]

# %%
# !tar -zxf /content/NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA-SingleNode.tar.gz

# %%
# !/content/NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA/namd3 /content/drive/MyDrive/NAMD/complex.conf > /content/drive/MyDrive/NAMD/complex.log
# Out:
# FATAL ERROR: ABNORMAL EOF FOUND - buffer=*RETURN*

# %%
# !/content/NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA/namd3 /content/drive/MyDrive/NAMD/ligand.conf > /content/drive/MyDrive/NAMD/ligand.log
# Out:
# FATAL ERROR: ABNORMAL EOF FOUND - buffer=*RETURN*

# %%
# !/content/NAMD_3.0alpha13_Linux-x86_64-multicore-CUDA/namd3 /content/drive/MyDrive/NAMD/protein.conf > /content/drive/MyDrive/NAMD/protein.log
# Out:
# FATAL ERROR: ABNORMAL EOF FOUND - buffer=*RETURN*
